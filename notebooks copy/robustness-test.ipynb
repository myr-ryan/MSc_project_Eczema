# %%
# !python ../src/eval_of_ad_identification.py --seg_type skin --perturb_type jun
# Out:
# /bin/bash: module: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `module'
# /bin/bash: scl: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `scl'
# /bin/sh: scl: line 1: syntax error: unexpected end of file
# /bin/sh: error importing function definition for `scl'
# /bin/sh: module: line 1: syntax error: unexpected end of file
# /bin/sh: error importing function definition for `module'
# Using TensorFlow backend.
# Segmentation Models: using `keras` framework.
# Program initiating... type of segmentation: skin, type of perturbation: blur
# reading test images from: /rds/general/user/zw120/home/EczemaNet/Eczema-Deep-Learning-Segmentation/data/perturbed_test_sets/adversarial_test_set_blur
# reading test masks from: /rds/general/user/zw120/home/EczemaNet/Eczema-Deep-Learning-Segmentation/data/test_set/labels
# ...
